# %%
pip install pytest
# Out:
# ...
#   Using cached tomli-2.4.1-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached tomli-2.4.1-py3-none-any.whl (14 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pytest]2m3/4 [pytest]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytest
from test_demo_calculate_xp import calculate_xp

# %%
pip install ipytest
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipytest

ipytest.autoconfig()

def test_calculate_xp_basic():
    assert calculate_xp(100, 1.5, 20) == 180.0

def test_calculate_xp_zero_score():
    assert calculate_xp(0, 2.0, 10) == 0

ipytest.run()
# Out:
# FF                                                                                           [100%]
# ============================================= FAILURES =============================================
# _____________________________________ test_calculate_xp_basic ______________________________________
#
#     def test_calculate_xp_basic():
# >       assert calculate_xp(100, 1.5, 20) == 180.0
# E       AssertionError
#
# /var/folders/dq/brcczj0n6lb2t6wmc28rh78c0000gn/T/ipykernel_35566/1770631182.py:6: AssertionError
# ___________________________________ test_calculate_xp_zero_score ___________________________________
#
#     def test_calculate_xp_zero_score():
# >       assert calculate_xp(0, 2.0, 10) == 0
# E       AssertionError
#
# /var/folders/dq/brcczj0n6lb2t6wmc28rh78c0000gn/T/ipykernel_35566/1770631182.py:9: AssertionError
# ===================================== short test summary info ======================================
# ...
