# %% [markdown]
# # Matplotlib Intro

# %%
# Matplotlib provides developers the ability to create a variety of basic plots, 
# visual ​tools that unlock hidden patterns, trends, and relationships within your data. ​

# Four Main Reasons: clarity, insight, communication, and decision making. 

# Benefits include: 
# simplified communication, 
# pattern recognition, 
# enhanced decision making, 
# storytelling with data

# %% [markdown]
# # Anatomy of a Matplotlib Plot

# %%
# The figure: 
# t's the overall container where your plot will reside, 
# providing the boundaries and context for your visualization. 

import matplotlib.pyplot as plt

# Create a figure with a specific size
fig = plt.figure(figsize=(10, 6))  # Width: 10 inches, Height: 6 inches

# %%
# Axes are where the actual plotting takes place.
# here that you'll plot your data points, lines, bars, or any other visual representation
# You can have multiple axes within a single figure, enabling you to create subplots 
# or side-by-side comparisons

# Creating subplots

# Create a figure with 2 rows and 2 columns of subplots
fig, ax = plt.subplots(2, 2)

# Access individual subplots using indexing
ax[0, 0].plot([1, 2, 3], [4, 5, 6])  # Top-left subplot
ax[0, 1].bar(['A', 'B', 'C'], [7, 8, 9])  # Top-right subplot
ax[1, 0].scatter([10, 20, 30], [11, 12, 13])  # Bottom-left subplot
ax[1, 1].hist([1, 1, 2, 3, 3, 3])  # Bottom-right subplot

plt.show()

# %%
# Labels are essential for providing context and clarity to your plot
# x-label and y-label describe what each axis represents

# Adding labels and title

x = [1, 2, 3]
y = [4, 5, 6]

plt.plot(x, y)
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Plot Title')
plt.show()

# %%
# Ticks are the marks along the axes indicating specific values
# Tick labels are the text associated with each tick

# Customizing ticks and tick labels

import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)

# Set tick locations and labels for the x-axis
plt.xticks(np.arange(0, 11, 2), ['0', '2', '4', '6', '8', '10'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.show()

# %%
# Legends: Decoding the symbol and unveiling the story 
# It acts as a key, decoding the different symbols, colors, or line styles used to represent each element

# Adding a Legend

x = [1, 2, 3]
y1 = [4, 5, 6]
y2 = [7, 8, 9]

plt.plot(x, y1, label='Data Series 1')
plt.plot(x, y2, label='Data Series 2')

plt.legend()  # Automatically creates a legend based on labels
plt.show()

# %%
# Customizing your Plot: 
# You have granular control over virtually every aspect of your plot, 
# from colors and fonts to line styles and marker shapes

# Scenario 1: enhancing readability with visual cues

# You can customize the font size, 
# increasing it for better legibility, especially for presentations or publications

# Adjusting tick frequency helps avoid overcrowding, ensuring each tick label is clearly visible

# Adding grid lines provides subtle visual cues, 
# making it easier to trace data points across the axes and interpret their values

# Scenario 2: Highlighting key points for emphasis

# Matplotlib empowers you to add annotations, such as text labels or arrows, directly on the plot

# You can place a label pinpointing the average grade or use an arrow to visually connect 
# it to the corresponding point on the distribution curve.

# Scenario 3: Creating subplots for comparative analysis

# If you're comparing multiple datasets or aspects of your data, 
# subplots offer a powerful solution for organizing and presenting your findings.

# You can create multiple axes within a single figure, each with its own plot.

# This arrangement allows for side-by-side comparisons, facilitating a more comprehensive view of your data 
# and revealing potential relationships or contrasts.

# NOTE: Addressing opposing viewpoints 

# it's easy to create cluttered and confusing visualizations if you're not careful
# Matplotlib's flexibility and control make it a valuable tool. Beginners can start with the basics and gradually add complexity, 
# while experienced users can customize every aspect of their plots.

# If interactivity is essential, consider combining Matplotlib with libraries like Plotly or Bokeh.
